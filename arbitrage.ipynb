# %% [markdown]
# # Optimize Arbitrage

# %% [markdown]
# ## Setup
# **Do NOT click the button at the top to run all cells!**
#
# This is an interactive document consisting of text parts (like this one) and code parts (with a greyish background). Click in the next line and press **Shift + Enter** to execute the code.

# %%
import importlib
from IPython.display import clear_output

if importlib.util.find_spec("pulp") is None :
    # %pip install pulp
    clear_output(wait=True) 

import pulp
from pulp import LpVariable
from pulp import LpProblem 
from pulp import *

# %%
#game data
rarities = [2,1.6,1.4,1.2]
all_products = { 120034: {"guid": 120034, "name": "Corn", "agio": 1, "weight": 265.47999799999997}, 112694: { "guid": 112694, "name": "Caribou Meat", "agio": 1, "weight": 645.70604 }, 112697: { "guid": 112697, "name": "Goose Feathers", "agio": 1.4, "weight": 184.308456 }, 114357: { "guid": 114357, "name": "Sanga Cow", "agio": 1, "weight": 136.8545464 }, 114369: { "guid": 114369, "name": "Spices", "agio": 1.4, "weight": 203.0659098 }, 114370: { "guid": 114370, "name": "Beeswax", "agio": 1, "weight": 162.3818196 }, 114390: { "guid": 114390, "name": "Hibiscus Tea", "agio": 1.2, "weight": 279.086366 }, 114391: { "guid": 114391, "name": "Linen", "agio": 1.2, "weight": 178.63181960000003 }, 114404: { "guid": 114404, "name": "Tapestries", "agio": 1.2, "weight": 914.1698670000001 }, 114410: { "guid": 114410, "name": "Seafood Stew", "agio": 1.4, "weight": 1353.99171726 }, 114414: { "guid": 114414, "name": "Clay Pipes", "agio": 1.4, "weight": 1161.0965455 }, 114428: { "guid": 114428, "name": "Leather Boots", "agio": 1.4, "weight": 554.2391464 }, 114430: { "guid": 114430, "name": "Tailored Suits", "agio": 1.2, "weight": 983.7046155999999 }, 114431: { "guid": 114431, "name": "Telephones", "agio": 1.6, "weight": 2926.4020599999994 }, 120008: { "guid": 120008, "name": "Wood", "agio": 1, "weight": 69.33594 }, 120016: { "guid": 120016, "name": "Champagne", "agio": 1.6, "weight": 1013.6174225 }, 120030: { "guid": 120030, "name": "Glasses", "agio": 1.4, "weight": 996.6566975000001 }, 120032: { "guid": 120032, "name": "Coffee", "agio": 1.4, "weight": 920.9361979999999 }, 120033: { "guid": 120033, "name": "Fried Plantains", "agio": 1, "weight": 250.70598909999995 }, 120035: { "guid": 120035, "name": "Tortillas", "agio": 1, "weight": 853.494558 }, 120037: { "guid": 120037, "name": "Bowler Hats", "agio": 1.4, "weight": 449.4541519999999 }, 120041: { "guid": 120041, "name": "Plantains", "agio": 1, "weight": 113.57999799999999 }, 120044: { "guid": 120044, "name": "Felt", "agio": 1.2, "weight": 78.05999599999998 }, 1010192: { "guid": 1010192, "name": "Grain", "agio": 1, "weight": 177.34376 }, 1010193: { "guid": 1010193, "name": "Beef", "agio": 1, "weight": 157.34376 }, 1010194: { "guid": 1010194, "name": "Hops", "agio": 1.2, "weight": 183.34376 }, 1010195: { "guid": 1010195, "name": "Potatoes", "agio": 1, "weight": 61.84376 }, 1010196: { "guid": 1010196, "name": "Timber", "agio": 1, "weight": 83.00782 }, 1010197: { "guid": 1010197, "name": "Wool", "agio": 1, "weight": 28.67188 }, 1010198: { "guid": 1010198, "name": "Red Peppers", "agio": 1, "weight": 244.67188 }, 1010199: { "guid": 1010199, "name": "Pigs", "agio": 1, "weight": 74.01563999999999 }, 1010200: { "guid": 1010200, "name": "Fish", "agio": 1, "weight": 70.43361 }, 1010201: { "guid": 1010201, "name": "Clay", "agio": 1, "weight": 106.46363 }, 1010203: { "guid": 1010203, "name": "Soap", "agio": 1, "weight": 205.39745 }, 1010204: { "guid": 1010204, "name": "Brass", "agio": 1.4, "weight": 201.736355 }, 1010206: { "guid": 1010206, "name": "Sewing Machines", "agio": 1.4, "weight": 812.7386999999999 }, 1010208: { "guid": 1010208, "name": "Light Bulbs", "agio": 1.4, "weight": 1780.6027725 }, 1010209: { "guid": 1010209, "name": "Furs", "agio": 1.2, "weight": 387.67188 }, 1010213: { "guid": 1010213, "name": "Bread", "agio": 1.2, "weight": 269.56109000000004 }, 1010214: { "guid": 1010214, "name": "Beer", "agio": 1.4, "weight": 517.77842 }, 1010215: { "guid": 1010215, "name": "Goulash", "agio": 1.2, "weight": 636.70794 }, 1010216: { "guid": 1010216, "name": "Schnapps", "agio": 1, "weight": 121.20316 }, 1010217: { "guid": 1010217, "name": "Canned Food", "agio": 1.4, "weight": 987.3638699999999 }, 1010219: { "guid": 1010219, "name": "Steel", "agio": 1.2, "weight": 347.01815999999997 }, 1010222: { "guid": 1010222, "name": "Dynamite", "agio": 1, "weight": 1412.0550425000001 }, 1010225: { "guid": 1010225, "name": "Steam Carriages", "agio": 1.6, "weight": 7914.931003 }, 1010226: { "guid": 1010226, "name": "Coal", "agio": 1, "weight": 102.96363 }, 1010227: { "guid": 1010227, "name": "Iron", "agio": 1, "weight": 102.96363 }, 1010228: { "guid": 1010228, "name": "Quartz Sand", "agio": 1, "weight": 80.30454250000001 }, 1010229: { "guid": 1010229, "name": "Zinc", "agio": 1.2, "weight": 72.481815 }, 1010230: { "guid": 1010230, "name": "Copper", "agio": 1.2, "weight": 72.481815 }, 1010231: { "guid": 1010231, "name": "Cement", "agio": 1.2, "weight": 72.481815 }, 1010232: { "guid": 1010232, "name": "Saltpetre", "agio": 1, "weight": 197.30454250000003 }, 1010233: { "guid": 1010233, "name": "Gold Ore", "agio": 1.2, "weight": 149.481815 }, 1010234: { "guid": 1010234, "name": "Tallow", "agio": 1, "weight": 133.85199999999998 }, 1010236: { "guid": 1010236, "name": "Malt", "agio": 1.4, "weight": 219.116485 }, 1010237: { "guid": 1010237, "name": "Work Clothes", "agio": 1, "weight": 90.03128000000001 }, 1010238: { "guid": 1010238, "name": "Sausages", "agio": 1, "weight": 149.56108999999998 }, 1010240: { "guid": 1010240, "name": "Cotton Fabric", "agio": 1.4, "weight": 270.55999599999996 }, 1010241: { "guid": 1010241, "name": "Glass", "agio": 1, "weight": 338.5609425 }, 1010242: { "guid": 1010242, "name": "Wood Veneers", "agio": 1.4, "weight": 724.8750399999999 }, 1010243: { "guid": 1010243, "name": "Filaments", "agio": 1.2, "weight": 775.5027299999999 }, 1010245: { "guid": 1010245, "name": "Penny Farthings", "agio": 1, "weight": 1811.1224479999998 }, 1010246: { "guid": 1010246, "name": "Pocket Watches", "agio": 1.4, "weight": 2434.2299274999996 }, 1010247: { "guid": 1010247, "name": "Fur Coats", "agio": 1.2, "weight": 1162.7446759999998 }, 1010248: { "guid": 1010248, "name": "Gramophones", "agio": 1.4, "weight": 2310.835685 }, 1010249: { "guid": 1010249, "name": "Gold", "agio": 1.6, "weight": 797.894695 }, 1010250: { "guid": 1010250, "name": "Jewellery", "agio": 1.6, "weight": 1524.0192819999997 }, 1010252: { "guid": 1010252, "name": "Tobacco", "agio": 1.2, "weight": 588.879998 }, 1010255: { "guid": 1010255, "name": "Caoutchouc", "agio": 1.4, "weight": 231.87999799999997 }, 1010256: { "guid": 1010256, "name": "Pearls", "agio": 1.4, "weight": 344.239987 }, 1010257: { "guid": 1010257, "name": "Rum", "agio": 1.4, "weight": 267.45593199999996 }, 1010258: { "guid": 1010258, "name": "Chocolate", "agio": 1.2, "weight": 1012.116196 }, 1010259: { "guid": 1010259, "name": "Cigars", "agio": 1.6, "weight": 2083.3539379999997 } }
export_products = {1010224: {"guid": 1010224, "name": "Steam Motors", "weight": 2699.361665}, 1010223: {"guid": 1010223, "name": "Advanced Weapons", "weight": 4097.7803525}, 134623: {"guid": 134623, "name": "Elevators", "weight": 9870},}
products = all_products
w_steam = all_products[1010225]["weight"]

def addDemand(name, amount):
    global demands
    if not name in name_to_guid :
        raise ValueError(name + " not known or cannot be imported")
    
    guid = name_to_guid[name]
    if guid in demands:
        demands[guid] = max(0,  demands[guid] + amount)
    else:
        demands[guid] = max(0, amount)
        
def addExcessGood(name, amount):
    global demands, excessGoods
    if not name in name_to_guid:
        raise ValueError(name + " not known")
    
    guid = name_to_guid[name]
    
    if not guid in products:
        products[guid] = export_products[guid]
        products[guid]['agio'] = 1000
    
    if guid in demands:
        if amount >= demands[guid] :
            amount -= demands[guid]
            del demands
        else :
            demands[guid] -= amount
            return
    
    if guid in excessGoods:
        excessGoods[guid] = max(0, excessGoods[guid] + amount)
    else:
        excessGoods[guid] = max(0, amount)

# %%
# set island specific values, e.g. transfer time

global visitInterval, loadingSpeed, totalProfit, totalAmount, duration, storageCapacity
storageCapacity = 10000
visitInterval = 120 + 20 * 60 # seconds
loadingSpeed = 44 * 3 # t/s, Morris has a 200% loading speed buff

# set starting point for optimization - no need to change that
totalProfit = 6174189.609999999 / 1000 * storageCapacity
totalAmount = 1000 * 9 
duration = visitInterval + totalAmount / loadingSpeed
populationFactor = 1

#islands = {"A": {"name": "A", "capacity": 21000, "maxContracts": 4},"B": {"name": "B", "capacity": 5850, "maxContracts": 4} ,"C": {"name": "C", "capacity": 6650, "maxContracts": 4},"D": {"name": "D", "capacity": 6050, "maxContracts": 4}}

# %%
# define production / consumption scenario

global demands, population
population = 660000 # all values scale relative to this population count

def generate_demands():
    global demands, population, name_to_guid,sum_demands,excessGoods,summary,demandCarriages
    
    """#toasters, lamps, detergent, no violins
    demandCarriages = 23.76/60 #Steam Carriages
    demands = { # in t / s
        1010248: 1.052631, #Gramophones for Ketema
        120032: 397.56/60, #Coffe
        120030: 75.1/60, # Spectales
        1010208: 69.71/60, #Light Bulbs
        120016: 99.35/60, #Champagne
        1010259: 93.87/60, #Cigars
        1010258: 225.29/60, # Chocolate

        1010192: 103.57/60, # Grain
        1010234: 107.5352/60, # Tallow
        1010219: (59.14+7)/60, # Steel for typewriters and toasters
        1010204: (59.14+7)/60, # Brass for Typewriters and Lamps
        120008: 102.5/60, # Wood for Ethanol
        1010241: 7/60, # glass for Lamps
        1010228: 59.14/60, # Sand for Typewriters
        1010255: 2.18/60, # Caoutchouc for Chewing Gum
        1010232: 7/60, # Salpetre for Detergent 
        1010243: 7/60, # Filaments for Toasters
        1010229: 7/60, # Zinc for Toasters
        120044: 17.74079/60, # Felt
        120034: 68.18959/60, # Corn
    }"""


     
    #vacuum cleaners, lamps, detergent, no violins
    demandCarriages = 28.159972/60 #Steam Carriages
    demands = { # in t / s
        120032: 397.55528/60, #Coffe
        120030: 75.093258/60, # Spectales
        1010208: 105.6/60, #Light Bulbs
        120016: 99.34848/60, #Champagne
        1010259: 93.86657/60, #Cigars
        1010258: 225.28/60, # Chocolate
        
        #1010245: 205.29/60, # Penny Fatherings
        #1010246: 64.41/60, # Pocket Watches
        #1010250: 86.46/60, # Jewellery
        #1010248: 21.61/60, # Phonographen
        
    }
    

    name_to_guid = {}
    for guid in products :
        name_to_guid[products[guid]['name']] = guid

    for guid in export_products:
        name_to_guid[export_products[guid]['name']] = guid

    excessGoods = {}
    summary=[]



generate_demands()

# %%
   
# bicycles (clipped)
def add_bicycles_clipped(f):
    # Production (t/min):
    # 11.7 of Bicycles
    #f=11.5
    #f=2.393 # penny farthing production at the space of 140k residents (space in NW free for allocation)
    #f=10.477
    #f=1.04 # penny farthing production at the space of 30k residents (space in NW for vacuum cleaners)
    prodi=11.7
    addDemand("Caoutchouc", f*prodi/60)
    addExcessGood("Penny Farthings", f*prodi/60)
    addExcessGood("Pocket Watches", f*prodi/4/60)
    addExcessGood("Gramophones", f*prodi/4/60)
    addExcessGood("Steam Motors", 2*f*prodi/3/60)
    addExcessGood("Advanced Weapons", 2*f*prodi/3/60)

# bicycles (not clipped)
def add_bicycles(f):

    # Production (t/min):
    # 11.7 of Bicycles
    #f=11.5
    #f=2.393 # penny farthing production at the space of 140k residents (space in NW free for allocation)
    #f=10.477
    #f=10.477 # penny farthing production at the space of 30k residents (space in NW for vacuum cleaners)
    prodi=9
    addDemand("Caoutchouc", f*prodi/60)
    addExcessGood("Penny Farthings", f*prodi/60)
    addExcessGood("Pocket Watches", f*prodi/8/60)
    addExcessGood("Gramophones", f*prodi/8/60)
    addExcessGood("Steam Motors", f*prodi/3/60)
    addExcessGood("Advanced Weapons", f*prodi/3/60)

# %%
def defineProblem():
    global prob, profit, variables, profitVariables, amountVariables, sharedAmount, minProfit, excessGoods, demands, status, sumDemands
    sum_demands = sum([products[guid]['weight'] * products[guid]['agio']* demands[guid] for guid in demands])
    prob = LpProblem("Arbitrage", LpMaximize)
      
    if 'variables' in globals():
        old_variables = variables
        
    variables = {}
    profitVariables = []
    amountVariables = {}
    
    # determine products that need to be traded on both islands
    minProfit = 0
    sharedAmount = 0
    for guid in demands:
        if demands[guid] * populationFactor * duration > storageCapacity :
            minProfit += demands[guid] * populationFactor * duration * products[guid]['weight'] * products[guid]['agio'] / 2
            sharedAmount = demands[guid] * populationFactor * duration / 2

    i = 1
    for r in rarities :
        weights = {}
        for guid in products : 
            p = products[guid]
            name = str(guid) + '_' + str(r)
            v = LpVariable(name, cat='Binary') # variable: (product, rarity)
            variables[name] = v
            weights[v] = 1
        name = "pyramid_slot_count_" + str(r)
        
        # Constraint 0: The n-th level of the pyramid must contain at most n products
        prob.constraints[name] = LpConstraint(LpAffineExpression(weights), LpConstraintLE, name, i)
        i = i+1

    for guid in products : 
        weights = {}
        for r in rarities :
            p = products[guid]
            name = str(guid) + '_' + str(r)
            v = variables[name]
            weights[v] = 1

        name = str(guid) + "_once_in_pyramid"
        
        # Constraint 1: Each product must occur at most once in pyramid
        prob.constraints[name] = LpConstraint(LpAffineExpression(weights), LpConstraintLE, name, 1)

    weights_objective = {}
    max_amount = LpVariable(name, 0)
    variables["max_amount"] = max_amount
    loadingAmountWeight = totalProfit  * loadingSpeed /(visitInterval * loadingSpeed + totalAmount) / (visitInterval * loadingSpeed + totalAmount)
    weights_objective[max_amount] = -loadingAmountWeight
    profitWeight = 1 / duration
    
    for island in islands:
        weights_dockland = {}
        slots = {}
        amountVariables[island] = []

        c = islands[island]["capacity"]                
        #print(loadingAmountWeight)

        weights_island_amount = {max_amount: -1}
        for guid in products :         
            for r in rarities :

                p = products[guid]

                for direction in ["export", "import"]:
                    name =  island + "_" + direction + "_" + str(guid) + '_' + str(r)
                    limit = 1
                    if guid in demands and direction == "export" :
                        limit = max(0,1- populationFactor * demands[guid] * duration / c)
                                            
                    v = LpVariable(name, 0, limit) #Each island has two continous variables for each product: export and import in [0,1]
                    variables[name] = v
                    weights_island_amount[v] = c
                    amountVariables[island].append(v)                    

                    # incorporate trade ratios and island storage
                    if direction == "export" :
                        weights_dockland[v] = -r * p["weight"] * c
                    else :
                        weights_dockland[v] = p["weight"] * p["agio"] * c

                    name_slag =  island + "_slag_" + direction + "_" + str(guid) + '_' + str(r)
                    v_slag = LpVariable(name_slag, 0, 1)
                    variables[name_slag] = v_slag 

                    name_bin =  island + "_" + direction + "_binary_" + str(guid) + '_' + str(r)
                    v_bin = LpVariable(name_bin, cat='Binary') # Create binary variable to indicate whether the product is imported, or exported respectively.
                    variables[name_bin] = v_bin
                    slots[v_bin] = 1

                    name = island + "_" + direction + "_ceil_" + str(guid) + "_" + str(r)
                    
                    # Constraint 2: Ensure that the binary import/export variable is 1 if more than 0 tons are imported/exported
                    prob.constraints[name] = LpConstraint(LpAffineExpression({v : 1, v_slag : 1, v_bin:-1}), LpConstraintEQ, name, 0)

                name = island + "_import_export_nand_" + str(guid) + "_" + str(r)
                #Constraint 3: ensure that rarity matches and not both import and export occur
                prob.constraints[name] = LpConstraint(LpAffineExpression({
                    variables[island + "_import_binary_" + str(guid) + '_' + str(r)] : 1, 
                    variables[island + "_export_binary_" + str(guid) + '_' + str(r)] : 1, 
                    variables[str(guid) + '_' + str(r)] : -1, 
                }), LpConstraintLE, name, 0)


        name =  island + "_profit"
        v = LpVariable(name, minProfit)
        variables[name] = v
        profitVariables.append(v)
        weights_dockland[v] = 1
        weights_objective[v] = profitWeight

        name = island + "_import_export_consistency"
        # Constraint 4: Ensure that the summed goods value of import and export at one island is identical.
        prob.constraints[name] = LpConstraint(LpAffineExpression(weights_dockland), LpConstraintEQ, name, 0)

        # Constraint 5: Restrict the maximum number of contracts
        if "maxContracts" in islands[island] :
            name = island + "_maximum_contracts"
            prob.constraints[name] = LpConstraint(LpAffineExpression(slots), LpConstraintLE, name, islands[island]["maxContracts"] + 1)

        name = island + "_summed_amount"
        prob.constraints[name] = LpConstraint(LpAffineExpression(weights_island_amount), LpConstraintLE, name, 0)
        
    for guid in products : 
        for r in rarities :
            weights_global = {}

            p = products[guid]

            for island in islands:
                weights_global[variables[island + "_export_" + str(guid) + '_' + str(r)]] = islands[island]["capacity"]
                weights_global[variables[island + "_import_" + str(guid) + '_' + str(r)]] = -islands[island]["capacity"]

            name = str(guid) + '_' + str(r) + "_good_consistency"
            
            # Constraint 5: Ensure that the sum of imports and exports for one arbitrage goods is the same. 
            # Consumed goods are not considered here.
            if guid in excessGoods :
                # Allow more goods to be exported if we have excess goods
                prob.constraints[name] = LpConstraint(LpAffineExpression(weights_global), LpConstraintLE, name, excessGoods[guid] * duration * populationFactor)
            else :
                rhs = 0
                if guid == 1010225 and  r == 2:
                    rhs = -min(storageCapacity,demandCarriages * duration * populationFactor)
                prob.constraints[name] = LpConstraint(LpAffineExpression(weights_global), LpConstraintEQ, name, rhs)

    
    #for i in ["A_import_120035_1.4", "A_export_120035_1.4"]:
    #    variables[i].setInitialValue(0)
    #    variables[i].fixValue()
    
    #i = "1010248_1.4" #Gramophones
    #variables[i].setInitialValue(1)
    #variables[i].fixValue()
    
    #i = "1010223_1.2" #Advanced Weapons
    #variables[i].setInitialValue(1)
    #variables[i].fixValue()
    
    if 'old_variables' in locals():
        for name in old_variables:
            if not name in variables :
                continue
            v = variables[name]  
            val = value(old_variables[name])
            
            if val == None:
                continue
            
            
            if not v.upBound == None :
                val = min(val, v.upBound)
                
            if not v.lowBound == None:
                val = max(val, v.lowBound)
            
            v.setInitialValue(val)
                
    
    prob.objective = LpAffineExpression(weights_objective)
    
def solve():
    global status
    status = prob.solve(apis.CPLEX_CMD(timeLimit = 120, warmStart=True))
    status = prob.solve(apis.PULP_CBC_CMD(timeLimit = 120, gapAbs=0.1, warmStart=True))
    #status = prob.solve(apis.COIN_CMD(timeLimit = 120, gapAbs=0.001, warmStart=True, threads=8))
    #print(LpStatus[status])
    
def optimize():
    defineProblem()
    solve()

def fixPyramid(pyramid):
    for r in range(len(pyramid)):
        for name in pyramid[r] :
            n = str(name_to_guid[name]) + "_" + str(rarities[r])
            variables[n].setInitialValue(1)
            variables[n].fixValue()
    
def update_variables(logStatus = True):
    global totalProfit,totalAmount,duration,profitPerMinute,profit,populationFactor,sharedAmount,status,error
    oldDuration = duration
    totalProfit = sum([value(v) for v in profitVariables]) #+ sum([products[guid]["weight"] * min(storageCapacity,demands[guid] * duration ) for guid in demands])
    totalAmount = max([sum([abs(value(v)) * islands[island]["capacity"] for v in amountVariables[island]]) for island in islands]) +  sum([demands[guid] * duration * populationFactor  for guid in demands]) - sharedAmount
    duration = visitInterval + totalAmount / loadingSpeed  
    error = abs(1-duration/oldDuration)
    sum_demands = sum([products[guid]['weight'] * products[guid]['agio']* demands[guid] for guid in demands])
    populationFactor = totalProfit / duration / sum_demands
    profitPerMinute = totalProfit / duration * 60
    profit = totalProfit / max([islands[island]["capacity"] for island in islands])
    if logStatus :
        print("{}, Profit {:.2f} t/min, {:.2f} min, Error {:.2%}".format(LpStatus[status], profitPerMinute/2/w_steam, duration/60, error))

def print_result():
    global summary
    min_weight_good = 0
    min_weight_good_weight = 999999999999
    min_weight_good_rarity = 0
    
    slots = 0

    #print results
    print()
    print("Pyramid:")
    i = 1
    for r in rarities :
        output = ""
        for v in prob.constraints["pyramid_slot_count_" + str(r)].toDict()['coefficients']:
            guid = int(v['name'].split('_')[0])
            if value(variables[v['name']]) > 0 and sum([value(variables[island + "_export_" + str(guid) + "_" + str(r)]) for island in islands]) > 0:
                slots += 1
                p = products[guid]
                if p['weight'] < min_weight_good_weight:
                    min_weight_good = p
                    min_weight_good_weight = p['weight']
                    min_weight_good_rarity = r

                if output:
                    output += ", "
                output += p['name']
        output = str(i) + ": " + output
        print(output)
        i = i+1

    print()

    contracts = {}
    for island in islands:
        contracts[island] = {"import": "", "export":""}


    for v in variables:
        if value(variables[v]) == 0:
            continue

        name = v.split('_')[0]
        direction = v.split('_')[1]

        if direction == "export" or direction == "import":
            guid = v.split('_')[2]
            if guid == 'binary':
                continue


                
            if contracts[name][direction]:
                contracts[name][direction] += ", "

            contracts[name][direction] += products[int(guid)]['name'] +  " (" + str(value(variables[v]) * islands[name]['capacity']) + "t)"
        if direction == "profit":
            contracts[name]["profit"] =  value(variables[v])

    for island in islands:
        if value(variables[island + "_import_1010225_2"]) > 0 :
            for guid in demands :
                if demands[guid] * populationFactor * duration > storageCapacity :
                    contracts[island]["import"] += ", " + products[int(guid)]['name'] +  " (" + str(demands[guid] * populationFactor * duration / 2) + "t)"
        else :
            for guid in demands :
              
                amount = demands[guid] * duration * populationFactor

                if amount > storageCapacity:
                    amount /= 2

                contracts[island]["import"] += ", " + products[int(guid)]['name'] +  " (" + str(amount) + "t)"
        
        print("Island " + island + ":")
        print("Export: " + contracts[island]["export"])
        print("Import: " + contracts[island]["import"])
        if "profit" in contracts[island]:
            print("Profit: " + str(contracts[island]["profit"]))
        print()

    #print("Total profit: " + str(profitPerMinute) + " or " + str(profitPerMinute/2/w_steam) + " t of legendary Steam Carriages per minute")
    #print("Trading interval: " + str(duration / 60) + " min")
    #print()
    #print("Supplied population: " + str(population * populationFactor))

    totalProfit_ = totalProfit - (storageCapacity * min_weight_good['weight'] * min_weight_good_rarity / 1.6 * 2- storageCapacity * min_weight_good['weight'] * min_weight_good['agio'])
    #print(totalProfit)
    #print(totalProfit_)
    totalAmount_ = totalAmount - storageCapacity
    duration_ = visitInterval + totalAmount_ / loadingSpeed   
    profitPerMinute_ = totalProfit_ / duration_ * 60
    #print("With one slot less: "+str(profitPerMinute_/2/w_steam) + " t/min of legendary Steam Carriages, trading every " + str(duration_ / 60) + " min")
    
    #print()
    #smallIslandStorage = storageCapacity / duration *(visitInterval + (sharedAmount + min([sum([abs(value(v)) * islands[island]["capacity"] for v in amountVariables[island]]) for island in islands])) / loadingSpeed   )
    x = (sharedAmount + min([sum([abs(value(v)) * islands[island]["capacity"] for v in amountVariables[island]]) for island in islands])) /duration / loadingSpeed
    smallIslandStorage =storageCapacity / duration  * visitInterval *(1-x/(x-1))
    minGoodWeight = profitPerMinute / 1.2 / loadingSpeed / 60
    summary.append(str(storageCapacity) +  "\tH\t" + str(profit) + "\t" + str(profitPerMinute/2/w_steam) + "\t" + str(duration/60) + "\t" + str(slots-1) + "\t" + str(population * populationFactor) + "\t" + str(smallIslandStorage) + "\t" + str(minGoodWeight))
    print(summary[-1])

# %%
def supplyable_population(factories):
    generate_demands()
    add_bicycles_and_elevators(factories)
    for i in range(7) :
        defineProblem()
        #fixPyramid(pyramid)
        solve()
        update_variables(False)
        if error < 0.0001:
            break
    return population * populationFactor



def estimate_factories(lower_init = 0, upper_init = 20):
    epsilon =  1000
    
    #base = {'factories': 0, 'pop': supplyable_population(0)}
    #if base['pop'] > population :
        #return 0
    
    lower = {'factories': lower_init, 'pop': supplyable_population(lower_init)}

    
    upper = {'factories': upper_init, 'pop': supplyable_population(upper_init)} 
    while True:
        center = lower['factories']+(upper['factories']-lower['factories'])*(targetPopulation  - lower['pop'])/(upper['pop'] - lower['pop'])

        print(lower['factories'], lower['pop'],upper['factories'], upper['pop'], center)
        
        
        if abs(lower['pop']-targetPopulation) < epsilon or abs(upper['pop']-targetPopulation) < epsilon :
            return center
        
        pop = supplyable_population(center)
        if pop > upper['pop']:
            upper = {'factories': center, 'pop': pop}
        elif pop < lower['pop']:
            lower = {'factories': center, 'pop': pop}
        elif pop > targetPopulation:
            upper = {'factories': center, 'pop': pop}
        else :
            lower = {'factories': center, 'pop': pop}

# %% [markdown]
# ## Calculate the best pyramid for an arbitrage system consisting of two islands

# %%
storageCapacity = 6000
islands = {"A": {"name": "A", "capacity": storageCapacity, "maxContracts": 8},"B": {"name": "B", "capacity": storageCapacity, "maxContracts": 8} }
for i in range(7) :
    defineProblem()
    #fixPyramid(pyramid)
    solve()
    update_variables(True)

print_result()
# Out:
# Optimal, Profit 57.92 t/min, 30.02 min, Error 0.31%
# Optimal, Profit 60.84 t/min, 29.76 min, Error 0.86%
# Optimal, Profit 60.03 t/min, 29.83 min, Error 0.24%
# Optimal, Profit 60.25 t/min, 29.82 min, Error 0.06%
# Optimal, Profit 60.19 t/min, 29.82 min, Error 0.02%
# Optimal, Profit 60.21 t/min, 29.82 min, Error 0.00%
# Optimal, Profit 60.21 t/min, 29.82 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (6000.0t), Tailored Suits (6000.0t), Tortillas (6000.0t), Dynamite (6000.0t), Penny Farthings (6000.0t), Pocket Watches (6000.0t), Fur Coats (6000.0t)
# Import: Steam Carriages (6000.0t), Coffee (3469.539018296721t)
# Profit: 5457725.9
#
# Island B:
# Export: Steam Carriages (5508.45504t)
# Import: Caribou Meat (6000.0t), Tailored Suits (6000.0t), Tortillas (6000.0t), Dynamite (6000.0t), Penny Farthings (6000.0t), Pocket Watches (6000.0t), Fur Coats (6000.0t), Coffee (3469.5390182967208t), Glasses (1310.7057143953537t), Light Bulbs (1843.1817599410765t), Champagne (1734.0653997525649t), Cigars (1638.3820993582601t), Chocolate (3932.121087874297t)
# Profit: 22961849.0
#
# 6000	H	4736.595816666666	60.20644834700003	29.819299710578395	7	386323.1568629041	5645.20953910221	100.27985787083094

# %% [markdown]
# ## Calculate the best arbitrage for storage capacities from 4kt to 16kt

# %%
# If the error does not reach 0.00%, the optimisation oscillated between several solutions and the output is not valid

global storageCapacity, summary
summary = []
for s in range(4000,14250,250):
    storageCapacity = s
    islands = {"A": {"name": "A", "capacity": storageCapacity, "maxContracts": 8},"B": {"name": "B", "capacity": storageCapacity, "maxContracts": 8} }
    for i in range(7) :
        defineProblem()
        #fixPyramid(pyramid)
        solve()
        update_variables(True)

    print_result()

for entry in summary:
    print(entry)
# Out:
# Optimal, Profit 37.03 t/min, 27.90 min, Error 6.45%
# Optimal, Profit 45.92 t/min, 27.17 min, Error 2.61%
# Optimal, Profit 43.39 t/min, 27.26 min, Error 0.35%
# Optimal, Profit 44.14 t/min, 27.20 min, Error 0.23%
# Optimal, Profit 43.94 t/min, 27.22 min, Error 0.06%
# Optimal, Profit 43.99 t/min, 27.21 min, Error 0.02%
# Optimal, Profit 43.98 t/min, 27.21 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (3672.2411199999997t)
# Import: Caribou Meat (4000.0t), Tailored Suits (4000.0t), Tortillas (4000.0t), Dynamite (4000.0t), Penny Farthings (4000.0t), Pocket Watches (4000.0t), Fur Coats (4000.0t), Coffee (2312.90571595449t), Glasses (873.7583646623697t), Light Bulbs (1228.72393295742t), Champagne (1155.9834761263405t), Cigars (1092.1979267388538t), Chocolate (2621.277723642496t)
# Profit: 15306914.0
#
# Island B:
# Export: Caribou Meat (4000.0t), Tailored Suits (4000.0t), Tortillas (4000.0t), Dynamite (4000.0t), Penny Farthings (4000.0t), Pocket Watches (4000.0t), Fur Coats (4000.0t)
# Import: Steam Carriages (4000.0t), Coffee (2312.90571595449t)
# Profit: 3638483.9
#
# 4000	H	4736.349475	43.97934505108558	27.213089154863066	7	282199.66271677456	3839.1154794113017	73.25199529387035
# Optimal, Profit 47.05 t/min, 27.47 min, Error 0.93%
# Optimal, Profit 45.94 t/min, 27.56 min, Error 0.34%
# Optimal, Profit 46.24 t/min, 27.53 min, Error 0.09%
# Optimal, Profit 46.16 t/min, 27.54 min, Error 0.03%
# Optimal, Profit 46.18 t/min, 27.54 min, Error 0.01%
# Optimal, Profit 46.18 t/min, 27.54 min, Error 0.00%
# Optimal, Profit 46.18 t/min, 27.54 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (4250.0t), Tailored Suits (4250.0t), Tortillas (4250.0t), Dynamite (4250.0t), Penny Farthings (4250.0t), Pocket Watches (4250.0t), Fur Coats (4250.0t)
# Import: Steam Carriages (4250.0t), Coffee (2457.6393347531352t)
# Profit: 3865889.2
#
# Island B:
# Export: Steam Carriages (3901.84782t)
# Import: Caribou Meat (4250.0t), Tailored Suits (4250.0t), Tortillas (4250.0t), Dynamite (4250.0t), Penny Farthings (4250.0t), Pocket Watches (4250.0t), Fur Coats (4250.0t), Coffee (2457.6393347531352t), Glasses (928.4351330238429t), Light Bulbs (1305.6132156007643t), Champagne (1228.320913237199t), Cigars (1160.5438853704t), Chocolate (2785.308193281631t)
# Profit: 16265046.0
#
# 4250	H	4736.690635294118	46.17908128628837	27.538579416853775	7	296314.580138101	4068.877516583906	76.91587587603134
# Optimal, Profit 49.19 t/min, 27.79 min, Error 0.92%
# Optimal, Profit 48.09 t/min, 27.88 min, Error 0.34%
# Optimal, Profit 48.39 t/min, 27.86 min, Error 0.09%
# Optimal, Profit 48.31 t/min, 27.87 min, Error 0.03%
# Optimal, Profit 48.33 t/min, 27.86 min, Error 0.01%
# Optimal, Profit 48.32 t/min, 27.86 min, Error 0.00%
# Optimal, Profit 48.32 t/min, 27.86 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (4500.0t), Tailored Suits (4500.0t), Tortillas (4500.0t), Dynamite (4500.0t), Penny Farthings (4500.0t), Pocket Watches (4500.0t), Fur Coats (4500.0t)
# Import: Steam Carriages (4500.0t), Coffee (2602.205321768308t)
# Profit: 4093294.4
#
# Island B:
# Export: Steam Carriages (4131.367785t)
# Import: Caribou Meat (4500.0t), Tailored Suits (4500.0t), Tortillas (4500.0t), Dynamite (4500.0t), Penny Farthings (4500.0t), Pocket Watches (4500.0t), Fur Coats (4500.0t), Coffee (2602.205321768308t), Glasses (983.0485742587574t), Light Bulbs (1382.413444383047t), Champagne (1300.5745684755705t), Cigars (1228.810685095856t), Chocolate (2949.1486813505t)
# Profit: 17221805.0
#
# 4500	H	4736.688755555555	48.32377440128681	27.864380059549436	7	310076.3056249295	4297.4497660220495	80.48807663946185
# Optimal, Profit 51.28 t/min, 28.12 min, Error 0.91%
# Optimal, Profit 50.18 t/min, 28.21 min, Error 0.33%
# Optimal, Profit 50.48 t/min, 28.18 min, Error 0.09%
# Optimal, Profit 50.40 t/min, 28.19 min, Error 0.02%
# Optimal, Profit 50.42 t/min, 28.19 min, Error 0.01%
# Optimal, Profit 50.42 t/min, 28.19 min, Error 0.00%
# Optimal, Profit 50.42 t/min, 28.19 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (4360.887695t)
# Import: Caribou Meat (4750.0t), Tailored Suits (4750.0t), Tortillas (4750.0t), Dynamite (4750.0t), Penny Farthings (4750.0t), Pocket Watches (4750.0t), Fur Coats (4750.0t), Coffee (2746.7714430744727t), Glasses (1037.6620662254754t), Light Bulbs (1459.2137445069995t), Champagne (1372.828290832185t), Cigars (1297.0775482360643t), Chocolate (3112.989321614932t)
# Profit: 18178565.0
#
# Island B:
# Export: Caribou Meat (4750.0t), Tailored Suits (4750.0t), Tortillas (4750.0t), Dynamite (4750.0t), Penny Farthings (4750.0t), Pocket Watches (4750.0t), Fur Coats (4750.0t)
# Import: Steam Carriages (4750.0t), Coffee (2746.7714430744727t)
# Profit: 4320699.7
#
# 4750	H	4736.687305263158	50.418896510397325	28.190180708433036	7	323519.9517696065	4524.881692754711	83.97771193754048
# Optimal, Profit 53.32 t/min, 28.44 min, Error 0.90%
# Optimal, Profit 52.23 t/min, 28.54 min, Error 0.33%
# Optimal, Profit 52.53 t/min, 28.51 min, Error 0.09%
# Optimal, Profit 52.45 t/min, 28.52 min, Error 0.02%
# Optimal, Profit 52.47 t/min, 28.52 min, Error 0.01%
# Optimal, Profit 52.46 t/min, 28.52 min, Error 0.00%
# Optimal, Profit 52.47 t/min, 28.52 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (4590.40765t)
# Import: Caribou Meat (5000.0t), Tailored Suits (5000.0t), Tortillas (5000.0t), Dynamite (5000.0t), Penny Farthings (5000.0t), Pocket Watches (5000.0t), Fur Coats (5000.0t), Coffee (2891.3374300896457t), Glasses (1092.27550746039t), Light Bulbs (1536.0139732892824t), Champagne (1445.0819460705568t), Cigars (1365.3443479615203t), Chocolate (3276.8298096838025t)
# Profit: 19135324.0
#
# Island B:
# Export: Caribou Meat (5000.0t), Tailored Suits (5000.0t), Tortillas (5000.0t), Dynamite (5000.0t), Penny Farthings (5000.0t), Pocket Watches (5000.0t), Fur Coats (5000.0t)
# Import: Steam Carriages (5000.0t), Coffee (2891.3374300896457t)
# Profit: 4548104.9
#
# 5000	H	4736.68578	52.46614195042674	28.515981289249332	7	336656.39052292745	4751.181822648902	87.38760385758239
# Optimal, Profit 55.32 t/min, 28.77 min, Error 0.89%
# Optimal, Profit 54.23 t/min, 28.86 min, Error 0.32%
# Optimal, Profit 54.53 t/min, 28.84 min, Error 0.09%
# Optimal, Profit 54.45 t/min, 28.84 min, Error 0.02%
# Optimal, Profit 54.47 t/min, 28.84 min, Error 0.01%
# Optimal, Profit 54.47 t/min, 28.84 min, Error 0.00%
# Optimal, Profit 54.47 t/min, 28.84 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (4819.9276125t)
# Import: Caribou Meat (5250.0t), Tailored Suits (5250.0t), Tortillas (5250.0t), Dynamite (5250.0t), Penny Farthings (5250.0t), Pocket Watches (5250.0t), Fur Coats (5250.0t), Coffee (3035.90355139581t), Glasses (1146.8889994271078t), Light Bulbs (1612.8142734132346t), Champagne (1517.3356684271712t), Cigars (1433.6112111017285t), Chocolate (3440.670449948234t)
# Profit: 20092084.0
#
# Island B:
# Export: Caribou Meat (5250.0t), Tailored Suits (5250.0t), Tortillas (5250.0t), Dynamite (5250.0t), Penny Farthings (5250.0t), Pocket Watches (5250.0t), Fur Coats (5250.0t)
# Import: Steam Carriages (5250.0t), Coffee (3035.90355139581t)
# Profit: 4775510.2
#
# 5250	H	4736.68460952381	54.46713787782201	28.841781876253563	7	349496.06276344537	4976.358571949727	90.7204625912982
# Optimal, Profit 57.27 t/min, 29.09 min, Error 0.88%
# Optimal, Profit 56.19 t/min, 29.19 min, Error 0.32%
# Optimal, Profit 56.49 t/min, 29.16 min, Error 0.09%
# Optimal, Profit 56.41 t/min, 29.17 min, Error 0.02%
# Optimal, Profit 56.43 t/min, 29.17 min, Error 0.01%
# Optimal, Profit 56.42 t/min, 29.17 min, Error 0.00%
# Optimal, Profit 56.42 t/min, 29.17 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (5500.0t), Tailored Suits (5500.0t), Tortillas (5500.0t), Dynamite (5500.0t), Penny Farthings (5500.0t), Pocket Watches (5500.0t), Fur Coats (5500.0t)
# Import: Steam Carriages (5500.0t), Coffee (3180.4695384109828t)
# Profit: 5002915.4
#
# Island B:
# Export: Steam Carriages (5049.44759t)
# Import: Caribou Meat (5500.0t), Tailored Suits (5500.0t), Tortillas (5500.0t), Dynamite (5500.0t), Penny Farthings (5500.0t), Pocket Watches (5500.0t), Fur Coats (5500.0t), Coffee (3180.4695384109828t), Glasses (1201.5024406620223t), Light Bulbs (1689.6145021955174t), Champagne (1589.5893236655427t), Cigars (1501.8780108271844t), Chocolate (3604.510938017104t)
# Profit: 21048843.0
#
# 5500	H	4736.683345454545	56.42342924568309	29.167582518949224	7	362048.88190035766	5200.420276628219	93.97886141250714
# Optimal, Profit 59.18 t/min, 29.42 min, Error 0.87%
# Optimal, Profit 58.11 t/min, 29.51 min, Error 0.32%
# Optimal, Profit 58.40 t/min, 29.49 min, Error 0.09%
# Optimal, Profit 58.32 t/min, 29.49 min, Error 0.02%
# Optimal, Profit 58.34 t/min, 29.49 min, Error 0.01%
# Optimal, Profit 58.33 t/min, 29.49 min, Error 0.00%
# Optimal, Profit 58.34 t/min, 29.49 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (5750.0t), Tailored Suits (5750.0t), Tortillas (5750.0t), Dynamite (5750.0t), Penny Farthings (5750.0t), Pocket Watches (5750.0t), Fur Coats (5750.0t)
# Import: Steam Carriages (5750.0t), Coffee (3325.0355254261553t)
# Profit: 5230320.6
#
# Island B:
# Export: Steam Carriages (5278.9675325t)
# Import: Caribou Meat (5750.0t), Tailored Suits (5750.0t), Tortillas (5750.0t), Dynamite (5750.0t), Penny Farthings (5750.0t), Pocket Watches (5750.0t), Fur Coats (5750.0t), Coffee (3325.035525426156t), Glasses (1256.115881896937t), Light Bulbs (1766.4147309778002t), Champagne (1661.8429789039144t), Cigars (1570.1448105526406t), Chocolate (3768.351426085974t)
# Profit: 22005602.0
#
# 5750	H	4736.682191304348	58.33650012733931	29.49338309976552	7	374324.3706992374	5423.375216400787	97.16527219368506
# Optimal, Profit 61.04 t/min, 29.75 min, Error 0.86%
# Optimal, Profit 59.98 t/min, 29.84 min, Error 0.31%
# Optimal, Profit 60.27 t/min, 29.81 min, Error 0.09%
# Optimal, Profit 60.19 t/min, 29.82 min, Error 0.02%
# Optimal, Profit 60.21 t/min, 29.82 min, Error 0.01%
# Optimal, Profit 60.21 t/min, 29.82 min, Error 0.00%
# Optimal, Profit 60.21 t/min, 29.82 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (6000.0t), Tailored Suits (6000.0t), Tortillas (6000.0t), Dynamite (6000.0t), Penny Farthings (6000.0t), Pocket Watches (6000.0t), Fur Coats (6000.0t)
# Import: Steam Carriages (6000.0t), Coffee (3469.60164673232t)
# Profit: 5457725.9
#
# Island B:
# Export: Steam Carriages (5508.48744t)
# Import: Caribou Meat (6000.0t), Tailored Suits (6000.0t), Tortillas (6000.0t), Dynamite (6000.0t), Penny Farthings (6000.0t), Pocket Watches (6000.0t), Fur Coats (6000.0t), Coffee (3469.60164673232t), Glasses (1310.729373863655t), Light Bulbs (1843.215031101753t), Champagne (1734.096701260529t), Cigars (1638.411673692849t), Chocolate (3932.1920663504056t)
# Profit: 22962362.0
#
# 6000	H	4736.681316666666	60.207769267157566	29.819183748649117	7	386331.63273316773	5645.231549162986	100.28205799539059
# Optimal, Profit 62.87 t/min, 30.07 min, Error 0.85%
# Optimal, Profit 61.81 t/min, 30.17 min, Error 0.31%
# Optimal, Profit 62.10 t/min, 30.14 min, Error 0.08%
# Optimal, Profit 62.02 t/min, 30.15 min, Error 0.02%
# Optimal, Profit 62.04 t/min, 30.14 min, Error 0.01%
# Optimal, Profit 62.04 t/min, 30.15 min, Error 0.00%
# Optimal, Profit 62.04 t/min, 30.14 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (6250.0t), Tailored Suits (6250.0t), Tortillas (6250.0t), Dynamite (6250.0t), Penny Farthings (6250.0t), Pocket Watches (6250.0t), Fur Coats (6250.0t)
# Import: Steam Carriages (6250.0t), Coffee (3614.167633747493t)
# Profit: 5685131.1
#
# Island B:
# Export: Steam Carriages (5738.0074375t)
# Import: Caribou Meat (6250.0t), Tailored Suits (6250.0t), Tortillas (6250.0t), Dynamite (6250.0t), Penny Farthings (6250.0t), Pocket Watches (6250.0t), Fur Coats (6250.0t), Coffee (3614.167633747493t), Glasses (1365.3428150985694t), Light Bulbs (1920.0152598840355t), Champagne (1806.3503564989007t), Cigars (1706.6784734183052t), Chocolate (4096.032554419276t)
# Profit: 23919121.0
#
# 6250	H	4736.680336	62.038587675603196	30.144984329465412	7	398079.336951111	5865.997402875544	103.33146906059878
# Optimal, Profit 64.66 t/min, 30.40 min, Error 0.84%
# Optimal, Profit 63.60 t/min, 30.33 min, Error 0.24%
# Optimal, Profit 64.01 t/min, 30.45 min, Error 0.43%
# Optimal, Profit 63.78 t/min, 30.48 min, Error 0.07%
# Optimal, Profit 63.84 t/min, 30.47 min, Error 0.02%
# Optimal, Profit 63.83 t/min, 30.47 min, Error 0.01%
# Optimal, Profit 63.83 t/min, 30.47 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (5967.54379t)
# Import: Caribou Meat (6500.0t), Tailored Suits (6500.0t), Tortillas (6500.0t), Dynamite (6500.0t), Penny Farthings (6500.0t), Pocket Watches (6500.0t), Fur Coats (6500.0t), Coffee (3758.765496560979t), Glasses (1419.9682982188124t), Light Bulbs (1996.8324225845492t), Champagne (1878.6199431675439t), Cigars (1774.9603255000204t), Chocolate (4259.909168180372t)
# Profit: 24876141.0
#
# Island B:
# Export: Caribou Meat (6500.0t), Tailored Suits (6500.0t), Tortillas (6500.0t), Dynamite (6500.0t), Penny Farthings (6500.0t), Pocket Watches (6500.0t), Fur Coats (6500.0t)
# Import: Steam Carriages (6500.0t), Coffee (3758.7654965609795t)
# Profit: 5912536.4
#
# 6500	H	4736.719599999999	63.830919470340184	30.470726131073267	7	409580.0863907356	6085.692749341933	106.31677682360939
# Optimal, Profit 66.41 t/min, 30.72 min, Error 0.83%
# Optimal, Profit 65.36 t/min, 30.64 min, Error 0.26%
# Optimal, Profit 65.77 t/min, 30.59 min, Error 0.17%
# Optimal, Profit 65.67 t/min, 30.61 min, Error 0.04%
# Optimal, Profit 65.70 t/min, 30.60 min, Error 0.01%
# Optimal, Profit 65.69 t/min, 30.60 min, Error 0.00%
# Optimal, Profit 65.69 t/min, 30.60 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (6199.6049325t)
# Import: Caribou Meat (5290.67646t), Tailored Suits (6750.0t), Tortillas (6750.0t), Dynamite (6750.0t), Penny Farthings (6750.0t), Pocket Watches (6750.0t), Fur Coats (6750.0t), Coffee (3885.2349421724884t), Glasses (1467.7453153341278t), Light Bulbs (2064.0189203041887t), Champagne (1941.8290002221809t), Cigars (1834.6815953035755t), Chocolate (4403.240363315603t)
# Profit: 26815421.0
#
# Island B:
# Export: Caribou Meat (5290.67646t), Tailored Suits (6750.0t), Tortillas (6750.0t), Dynamite (6750.0t), Penny Farthings (6750.0t), Pocket Watches (6750.0t), Fur Coats (6750.0t)
# Import: Steam Carriages (6750.0t), Coffee (3885.234942172488t)
# Profit: 5009188.8
#
# 6750	H	4714.757007407407	65.69305371222086	30.60317658085778	7	421528.7330652523	6306.215672377091	109.41834753968878
# Optimal, Profit 68.25 t/min, 30.82 min, Error 0.70%
# Optimal, Profit 67.22 t/min, 30.95 min, Error 0.42%
# Optimal, Profit 67.47 t/min, 30.92 min, Error 0.10%
# Optimal, Profit 67.41 t/min, 30.92 min, Error 0.03%
# Optimal, Profit 67.43 t/min, 30.92 min, Error 0.01%
# Optimal, Profit 67.42 t/min, 30.92 min, Error 0.00%
# Optimal, Profit 67.42 t/min, 30.92 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (6429.21678t)
# Import: Caribou Meat (5486.66475t), Tailored Suits (7000.0t), Tortillas (7000.0t), Dynamite (7000.0t), Penny Farthings (7000.0t), Pocket Watches (7000.0t), Fur Coats (7000.0t), Coffee (4029.1269349045087t), Glasses (1522.1041382598844t), Light Bulbs (2140.461091730016t), Champagne (2013.7457950995993t), Cigars (1902.6301221510607t), Chocolate (4566.316995690701t)
# Profit: 27808510.0
#
# Island B:
# Export: Caribou Meat (5486.66475t), Tailored Suits (7000.0t), Tortillas (7000.0t), Dynamite (7000.0t), Penny Farthings (7000.0t), Pocket Watches (7000.0t), Fur Coats (7000.0t)
# Import: Steam Carriages (7000.0t), Coffee (4029.126934904509t)
# Profit: 5194743.2
#
# 7000	H	4714.750457142857	67.42399017517342	30.921828822887473	7	432635.5307099646	6523.890868141727	112.30139524062447
# Optimal, Profit 69.94 t/min, 31.14 min, Error 0.70%
# Optimal, Profit 68.92 t/min, 31.27 min, Error 0.41%
# Optimal, Profit 69.17 t/min, 31.23 min, Error 0.10%
# Optimal, Profit 69.11 t/min, 31.24 min, Error 0.03%
# Optimal, Profit 69.12 t/min, 31.24 min, Error 0.01%
# Optimal, Profit 69.12 t/min, 31.24 min, Error 0.00%
# Optimal, Profit 69.12 t/min, 31.24 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (6658.83152t)
# Import: Caribou Meat (5682.6189475t), Tailored Suits (7250.0t), Tortillas (7250.0t), Dynamite (7250.0t), Penny Farthings (7250.0t), Pocket Watches (7250.0t), Fur Coats (7250.0t), Coffee (4173.024128360422t), Glasses (1576.4649258900258t), Light Bulbs (2216.906026024157t), Champagne (2085.665189283527t), Cigars (1970.581104878962t), Chocolate (4729.399522184868t)
# Profit: 28801668.0
#
# Island B:
# Export: Caribou Meat (5682.6189475t), Tailored Suits (7250.0t), Tortillas (7250.0t), Dynamite (7250.0t), Penny Farthings (7250.0t), Pocket Watches (7250.0t), Fur Coats (7250.0t)
# Import: Steam Carriages (7250.0t), Coffee (4173.024128360422t)
# Profit: 5380271.2
#
# 7250	H	4714.750234482759	69.1197342197388	31.240466389327075	7	443516.5112446785	6740.51326894116	115.12582645095343
# Optimal, Profit 71.60 t/min, 31.46 min, Error 0.69%
# Optimal, Profit 70.58 t/min, 31.58 min, Error 0.41%
# Optimal, Profit 70.83 t/min, 31.55 min, Error 0.10%
# Optimal, Profit 70.77 t/min, 31.56 min, Error 0.02%
# Optimal, Profit 70.78 t/min, 31.56 min, Error 0.01%
# Optimal, Profit 70.78 t/min, 31.56 min, Error 0.00%
# Optimal, Profit 70.78 t/min, 31.56 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Steam Carriages (6888.44625t)
# Import: Caribou Meat (5878.5732t), Tailored Suits (7500.0t), Tortillas (7500.0t), Dynamite (7500.0t), Penny Farthings (7500.0t), Pocket Watches (7500.0t), Fur Coats (7500.0t), Coffee (4316.921211941885t), Glasses (1630.8256720123281t), Light Bulbs (2293.35090194784t), Champagne (2157.584528552528t), Cigars (2038.532035722065t), Chocolate (4892.481924155392t)
# Profit: 29794825.0
#
# Island B:
# Export: Caribou Meat (5878.5732t), Tailored Suits (7500.0t), Tortillas (7500.0t), Dynamite (7500.0t), Penny Farthings (7500.0t), Pocket Watches (7500.0t), Fur Coats (7500.0t)
# Import: Steam Carriages (7500.0t), Coffee (4316.921211941885t)
# Profit: 5565799.3
#
# 7500	H	4714.749906666666	70.7812341723632	31.559103962711113	7	454177.7597396233	6956.088342025454	117.8932207031651
# Optimal, Profit 73.22 t/min, 31.77 min, Error 0.68%
# Optimal, Profit 72.21 t/min, 31.90 min, Error 0.41%
# Optimal, Profit 72.46 t/min, 31.87 min, Error 0.10%
# Optimal, Profit 72.40 t/min, 31.88 min, Error 0.02%
# Optimal, Profit 72.41 t/min, 31.88 min, Error 0.01%
# Optimal, Profit 72.41 t/min, 31.88 min, Error 0.00%
# Optimal, Profit 72.41 t/min, 31.88 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Penny Farthings, Pocket Watches
# 3: Tailored Suits, Dynamite, Fur Coats
# 4: Caribou Meat, Tortillas
#
# Island A:
# Export: Caribou Meat (6074.527422499999t), Tailored Suits (7750.0t), Tortillas (7750.0t), Dynamite (7750.0t), Penny Farthings (7750.0t), Pocket Watches (7750.0t), Fur Coats (7750.0t)
# Import: Steam Carriages (7750.0t), Coffee (4460.818283315076t)
# Profit: 5751327.3
#
# Island B:
# Export: Steam Carriages (7118.0609699999995t)
# Import: Caribou Meat (6074.527422499999t), Tailored Suits (7750.0t), Tortillas (7750.0t), Dynamite (7750.0t), Penny Farthings (7750.0t), Pocket Watches (7750.0t), Fur Coats (7750.0t), Coffee (4460.818283315076t), Glasses (1685.1864135226485t), Light Bulbs (2369.795771385917t), Champagne (2229.5038617198707t), Cigars (2106.482960800191t), Chocolate (5055.5643122899555t)
# Profit: 30787982.0
#
# 7750	H	4714.749587096774	72.4095184997236	31.87774153849522	7	464625.87549610774	7170.623663082147	120.60529101131404
# Optimal, Profit 74.82 t/min, 32.09 min, Error 0.68%
# Optimal, Profit 73.82 t/min, 30.56 min, Error 4.78%
# Optimal, Profit 75.49 t/min, 30.36 min, Error 0.66%
# Optimal, Profit 75.08 t/min, 30.41 min, Error 0.16%
# Optimal, Profit 75.18 t/min, 30.40 min, Error 0.04%
# Optimal, Profit 75.15 t/min, 30.40 min, Error 0.01%
# Optimal, Profit 75.16 t/min, 30.40 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (784.412656t), Tortillas (8000.0t), Dynamite (8000.0t), Penny Farthings (8000.0t), Pocket Watches (8000.0t), Gramophones (8000.0t)
# Import: Steam Carriages (8000.0t), Coffee (4415.217042154256t)
# Profit: 5692249.9
#
# Island B:
# Export: Steam Carriages (7374.55216t)
# Import: Caribou Meat (784.412656t), Tortillas (8000.0t), Dynamite (8000.0t), Penny Farthings (8000.0t), Pocket Watches (8000.0t), Gramophones (8000.0t), Coffee (4415.217042154255t), Glasses (1667.9593966025875t), Light Bulbs (2345.570254539139t), Champagne (2206.7124954704223t), Cigars (2084.9491902236355t), Chocolate (5003.883209683497t)
# Profit: 30473532.0
#
# 8000	H	4520.7227375	75.1594932761939	30.397431362987284	6	482271.4760274053	7407.622513517215	125.1856488849994
# Optimal, Profit 77.67 t/min, 30.56 min, Error 0.54%
# Optimal, Profit 76.64 t/min, 30.68 min, Error 0.40%
# Optimal, Profit 76.89 t/min, 30.65 min, Error 0.10%
# Optimal, Profit 76.83 t/min, 30.66 min, Error 0.02%
# Optimal, Profit 76.85 t/min, 30.66 min, Error 0.01%
# Optimal, Profit 76.84 t/min, 30.66 min, Error 0.00%
# Optimal, Profit 76.84 t/min, 30.66 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (7604.980845t)
# Import: Caribou Meat (809.2317915t), Tortillas (8250.0t), Dynamite (8250.0t), Penny Farthings (8250.0t), Pocket Watches (8250.0t), Gramophones (8250.0t), Coffee (4553.147088607472t), Glasses (1720.065944221643t), Light Bulbs (2418.84516063753t), Champagne (2275.649527127788t), Cigars (2150.0823730127267t), Chocolate (5160.203009360064t)
# Profit: 31425220.0
#
# Island B:
# Export: Caribou Meat (809.2317915t), Tortillas (8250.0t), Dynamite (8250.0t), Penny Farthings (8250.0t), Pocket Watches (8250.0t), Gramophones (8250.0t)
# Import: Steam Carriages (8250.0t), Coffee (4553.147088607472t)
# Profit: 5870370.0
#
# 8250	H	4520.677575757576	76.84373091327274	30.659983044823186	6	493078.62407761964	7621.451347088595	127.99091502349576
# Optimal, Profit 79.33 t/min, 30.82 min, Error 0.53%
# Optimal, Profit 78.30 t/min, 30.95 min, Error 0.40%
# Optimal, Profit 78.55 t/min, 30.92 min, Error 0.10%
# Optimal, Profit 78.49 t/min, 30.92 min, Error 0.02%
# Optimal, Profit 78.50 t/min, 30.92 min, Error 0.01%
# Optimal, Profit 78.50 t/min, 30.92 min, Error 0.00%
# Optimal, Profit 78.50 t/min, 30.92 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (7835.434725t)
# Import: Caribou Meat (833.7555649999999t), Tortillas (8500.0t), Dynamite (8500.0t), Penny Farthings (8500.0t), Pocket Watches (8500.0t), Gramophones (8500.0t), Coffee (4691.120987173882t), Glasses (1772.1890580804913t), Light Bulbs (2492.1433630340007t), Champagne (2344.6084759423875t), Cigars (2215.236263601008t), Chocolate (5316.572507805868t)
# Profit: 32377496.0
#
# Island B:
# Export: Caribou Meat (833.7555649999999t), Tortillas (8500.0t), Dynamite (8500.0t), Penny Farthings (8500.0t), Pocket Watches (8500.0t), Gramophones (8500.0t)
# Import: Steam Carriages (8500.0t), Coffee (4691.120987173881t)
# Profit: 6048261.3
#
# 8500	H	4520.677329411765	78.5004249758141	30.92240746088112	6	503709.03490185994	7834.317060790604	130.75030458538438
# Optimal, Profit 80.95 t/min, 31.09 min, Error 0.53%
# Optimal, Profit 79.93 t/min, 31.21 min, Error 0.40%
# Optimal, Profit 80.18 t/min, 31.18 min, Error 0.10%
# Optimal, Profit 80.12 t/min, 31.19 min, Error 0.02%
# Optimal, Profit 80.13 t/min, 31.18 min, Error 0.01%
# Optimal, Profit 80.13 t/min, 31.18 min, Error 0.00%
# Optimal, Profit 80.13 t/min, 31.18 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (8065.8885125t)
# Import: Caribou Meat (858.27949375t), Tortillas (8750.0t), Dynamite (8750.0t), Penny Farthings (8750.0t), Pocket Watches (8750.0t), Gramophones (8750.0t), Coffee (4829.094885740291t), Glasses (1824.3121719393398t), Light Bulbs (2565.4415654304717t), Champagne (2413.5674247569877t), Cigars (2280.390154189289t), Chocolate (5472.942006251672t)
# Profit: 33329772.0
#
# Island B:
# Export: Caribou Meat (858.27949375t), Tortillas (8750.0t), Dynamite (8750.0t), Penny Farthings (8750.0t), Pocket Watches (8750.0t), Gramophones (8750.0t)
# Import: Steam Carriages (8750.0t), Coffee (4829.094885740291t)
# Profit: 6226152.6
#
# 8750	H	4520.677097142858	80.12923626878592	31.184831946044824	6	514160.5320074217	8046.204374918402	133.46325260743387
# Optimal, Profit 82.55 t/min, 31.35 min, Error 0.52%
# Optimal, Profit 81.53 t/min, 31.47 min, Error 0.39%
# Optimal, Profit 81.78 t/min, 31.44 min, Error 0.10%
# Optimal, Profit 81.72 t/min, 31.45 min, Error 0.02%
# Optimal, Profit 81.73 t/min, 31.45 min, Error 0.01%
# Optimal, Profit 81.73 t/min, 31.45 min, Error 0.00%
# Optimal, Profit 81.73 t/min, 31.45 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (8296.34238t)
# Import: Caribou Meat (882.803223t), Tortillas (9000.0t), Dynamite (9000.0t), Penny Farthings (9000.0t), Pocket Watches (9000.0t), Gramophones (9000.0t), Coffee (4967.068772098426t), Glasses (1876.4352811862054t), Light Bulbs (2638.739761341335t), Champagne (2482.5263674699277t), Cigars (2345.5440390125923t), Chocolate (5629.311490861515t)
# Profit: 34282048.0
#
# Island B:
# Export: Caribou Meat (882.803223t), Tortillas (9000.0t), Dynamite (9000.0t), Penny Farthings (9000.0t), Pocket Watches (9000.0t), Gramophones (9000.0t)
# Import: Steam Carriages (9000.0t), Coffee (4967.068772098427t)
# Profit: 6404043.8
#
# 9000	H	4520.676866666667	81.7308630239646	31.44725634413977	6	524437.5956968553	8257.120054463736	136.13092206446206
# Optimal, Profit 84.13 t/min, 31.61 min, Error 0.52%
# Optimal, Profit 83.10 t/min, 31.73 min, Error 0.39%
# Optimal, Profit 83.36 t/min, 31.70 min, Error 0.10%
# Optimal, Profit 83.29 t/min, 31.71 min, Error 0.02%
# Optimal, Profit 83.31 t/min, 31.71 min, Error 0.01%
# Optimal, Profit 83.31 t/min, 31.71 min, Error 0.00%
# Optimal, Profit 83.31 t/min, 31.71 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (8526.79615t)
# Import: Caribou Meat (907.3269962500001t), Tortillas (9250.0t), Dynamite (9250.0t), Penny Farthings (9250.0t), Pocket Watches (9250.0t), Gramophones (9250.0t), Coffee (5105.042670664836t), Glasses (1928.5583950450543t), Light Bulbs (2712.0379637378064t), Champagne (2551.485316284528t), Cigars (2410.6979296008735t), Chocolate (5785.68098930732t)
# Profit: 35234324.0
#
# Island B:
# Export: Caribou Meat (907.3269962500001t), Tortillas (9250.0t), Dynamite (9250.0t), Penny Farthings (9250.0t), Pocket Watches (9250.0t), Gramophones (9250.0t)
# Import: Steam Carriages (9250.0t), Coffee (5105.042670664837t)
# Profit: 6581935.1
#
# 9250	H	4520.676659459459	83.30598030218408	31.70968076016614	6	534544.5575930951	8467.070741535015	138.754437337766
# Optimal, Profit 85.67 t/min, 31.87 min, Error 0.52%
# Optimal, Profit 84.65 t/min, 32.00 min, Error 0.39%
# Optimal, Profit 84.91 t/min, 31.97 min, Error 0.10%
# Optimal, Profit 84.84 t/min, 31.97 min, Error 0.02%
# Optimal, Profit 84.86 t/min, 31.97 min, Error 0.01%
# Optimal, Profit 84.85 t/min, 31.97 min, Error 0.00%
# Optimal, Profit 84.86 t/min, 31.97 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (931.850725t), Tortillas (9500.0t), Dynamite (9500.0t), Penny Farthings (9500.0t), Pocket Watches (9500.0t), Gramophones (9500.0t)
# Import: Steam Carriages (9500.0t), Coffee (5243.016679105693t)
# Profit: 6759826.3
#
# Island B:
# Export: Steam Carriages (8757.250005t)
# Import: Caribou Meat (931.850725t), Tortillas (9500.0t), Dynamite (9500.0t), Penny Farthings (9500.0t), Pocket Watches (9500.0t), Gramophones (9500.0t), Coffee (5243.016679105693t), Glasses (1980.6815504117412t), Light Bulbs (2785.3362245047333t), Champagne (2620.444320014053t), Cigars (2475.8518720739517t), Chocolate (5942.050612276765t)
# Profit: 36186601.0
#
# 9500	H	4520.676557894736	84.85524253964967	31.97210515819796	6	544485.61697824	8676.063058021873	141.33488845626212
# Optimal, Profit 87.19 t/min, 32.14 min, Error 0.51%
# Optimal, Profit 86.18 t/min, 32.26 min, Error 0.38%
# Optimal, Profit 86.43 t/min, 32.23 min, Error 0.09%
# Optimal, Profit 86.37 t/min, 32.24 min, Error 0.02%
# Optimal, Profit 86.38 t/min, 32.23 min, Error 0.01%
# Optimal, Profit 86.38 t/min, 32.23 min, Error 0.00%
# Optimal, Profit 86.38 t/min, 32.23 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (956.37444825t), Tortillas (9750.0t), Dynamite (9750.0t), Penny Farthings (9750.0t), Pocket Watches (9750.0t), Gramophones (9750.0t)
# Import: Steam Carriages (9750.0t), Coffee (5380.990565463829t)
# Profit: 6937717.5
#
# Island B:
# Export: Steam Carriages (8987.703855t)
# Import: Caribou Meat (956.37444825t), Tortillas (9750.0t), Dynamite (9750.0t), Penny Farthings (9750.0t), Pocket Watches (9750.0t), Gramophones (9750.0t), Coffee (5380.99056546383t), Glasses (2032.8046596586075t), Light Bulbs (2858.634420415598t), Champagne (2689.4032627269944t), Cigars (2541.005756897255t), Chocolate (6098.420096886609t)
# Profit: 37138877.0
#
# 9750	H	4520.676358974359	86.37927743416738	32.234529555535325	6	554264.8015636838	8884.103544018111	143.87332091339007
# Optimal, Profit 88.69 t/min, 32.40 min, Error 0.51%
# Optimal, Profit 87.68 t/min, 32.52 min, Error 0.38%
# Optimal, Profit 87.93 t/min, 32.49 min, Error 0.09%
# Optimal, Profit 87.87 t/min, 32.50 min, Error 0.02%
# Optimal, Profit 87.88 t/min, 32.50 min, Error 0.01%
# Optimal, Profit 87.88 t/min, 32.50 min, Error 0.00%
# Optimal, Profit 87.88 t/min, 32.50 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (980.89838t), Tortillas (10000.0t), Dynamite (10000.0t), Penny Farthings (10000.0t), Pocket Watches (10000.0t), Gramophones (10000.0t)
# Import: Steam Carriages (10000.0t), Coffee (5518.964464030238t)
# Profit: 7115608.8
#
# Island B:
# Export: Steam Carriages (9218.1577t)
# Import: Caribou Meat (980.89838t), Tortillas (10000.0t), Dynamite (10000.0t), Penny Farthings (10000.0t), Pocket Watches (10000.0t), Gramophones (10000.0t), Coffee (5518.964464030238t), Glasses (2084.927773517456t), Light Bulbs (2931.932622812068t), Champagne (2758.3622115415938t), Cigars (2606.159647485536t), Chocolate (6254.789595332412t)
# Profit: 38091153.0
#
# 10000	H	4520.6761799999995	87.8786980429041	32.496954041077814	6	563886.0451170969	9091.198669773243	146.37075581714166
# Optimal, Profit 90.17 t/min, 32.66 min, Error 0.50%
# Optimal, Profit 89.15 t/min, 32.78 min, Error 0.38%
# Optimal, Profit 89.40 t/min, 32.75 min, Error 0.09%
# Optimal, Profit 89.34 t/min, 32.76 min, Error 0.02%
# Optimal, Profit 89.36 t/min, 32.76 min, Error 0.01%
# Optimal, Profit 89.35 t/min, 32.76 min, Error 0.00%
# Optimal, Profit 89.35 t/min, 32.76 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (9448.61154t)
# Import: Caribou Meat (1005.4221105t), Tortillas (10250.0t), Dynamite (10250.0t), Penny Farthings (10250.0t), Pocket Watches (10250.0t), Gramophones (10250.0t), Coffee (5656.9383503883755t), Glasses (2137.050882764322t), Light Bulbs (3005.230818722933t), Champagne (2827.321154254535t), Cigars (2671.31353230884t), Chocolate (6411.159079942257t)
# Profit: 39043429.0
#
# Island B:
# Export: Caribou Meat (1005.4221105t), Tortillas (10250.0t), Dynamite (10250.0t), Penny Farthings (10250.0t), Pocket Watches (10250.0t), Gramophones (10250.0t)
# Import: Steam Carriages (10250.0t), Coffee (5656.9383503883755t)
# Profit: 7293500.0
#
# 10250	H	4520.676	89.354095977323	32.75937843933058	6	573353.1437967705	9297.35489872248	148.82817855554532
# Optimal, Profit 91.62 t/min, 32.92 min, Error 0.50%
# Optimal, Profit 90.61 t/min, 33.05 min, Error 0.37%
# Optimal, Profit 90.86 t/min, 33.02 min, Error 0.09%
# Optimal, Profit 90.79 t/min, 33.02 min, Error 0.02%
# Optimal, Profit 90.81 t/min, 33.02 min, Error 0.01%
# Optimal, Profit 90.81 t/min, 33.02 min, Error 0.00%
# Optimal, Profit 90.81 t/min, 33.02 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1029.945882t), Tortillas (10500.0t), Dynamite (10500.0t), Penny Farthings (10500.0t), Pocket Watches (10500.0t), Gramophones (10500.0t)
# Import: Steam Carriages (10500.0t), Coffee (5794.9122489547835t)
# Profit: 7471391.3
#
# Island B:
# Export: Steam Carriages (9679.065375t)
# Import: Caribou Meat (1029.945882t), Tortillas (10500.0t), Dynamite (10500.0t), Penny Farthings (10500.0t), Pocket Watches (10500.0t), Gramophones (10500.0t), Coffee (5794.912248954784t), Glasses (2189.1739966231708t), Light Bulbs (3078.5290211194033t), Champagne (2896.2801030691344t), Cigars (2736.4674228971207t), Chocolate (6567.52857838806t)
# Profit: 39995705.0
#
# 10500	H	4520.675838095238	90.8060440682925	33.021802855135995	6	582669.7732526643	9502.578580852944	151.24654323567182
# Optimal, Profit 93.04 t/min, 33.19 min, Error 0.50%
# Optimal, Profit 92.04 t/min, 33.31 min, Error 0.37%
# Optimal, Profit 92.28 t/min, 33.28 min, Error 0.09%
# Optimal, Profit 92.22 t/min, 33.29 min, Error 0.02%
# Optimal, Profit 92.24 t/min, 33.28 min, Error 0.01%
# Optimal, Profit 92.23 t/min, 33.28 min, Error 0.00%
# Optimal, Profit 92.24 t/min, 33.28 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1054.469607t), Tortillas (10750.0t), Dynamite (10750.0t), Penny Farthings (10750.0t), Pocket Watches (10750.0t), Gramophones (10750.0t)
# Import: Steam Carriages (10750.0t), Coffee (5932.88625739564t)
# Profit: 7649282.5
#
# Island B:
# Export: Steam Carriages (9909.519205t)
# Import: Caribou Meat (1054.469607t), Tortillas (10750.0t), Dynamite (10750.0t), Penny Farthings (10750.0t), Pocket Watches (10750.0t), Gramophones (10750.0t), Coffee (5932.88625739564t), Glasses (2241.297151989858t), Light Bulbs (3151.8272818863306t), Champagne (2965.23910679866t), Cigars (2801.6213653701993t), Chocolate (6723.898201357506t)
# Profit: 40947982.0
#
# 10750	H	4520.67576744186	92.23509859122721	33.28422725269432	6	591839.5029043362	9706.876036571828	153.62677638982865
# Optimal, Profit 94.45 t/min, 33.45 min, Error 0.49%
# Optimal, Profit 93.44 t/min, 33.57 min, Error 0.37%
# Optimal, Profit 93.69 t/min, 33.54 min, Error 0.09%
# Optimal, Profit 93.63 t/min, 33.55 min, Error 0.02%
# Optimal, Profit 93.64 t/min, 33.55 min, Error 0.01%
# Optimal, Profit 93.64 t/min, 33.55 min, Error 0.00%
# Optimal, Profit 93.64 t/min, 33.55 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1078.993344t), Tortillas (11000.0t), Dynamite (11000.0t), Penny Farthings (11000.0t), Pocket Watches (11000.0t), Gramophones (11000.0t)
# Import: Steam Carriages (11000.0t), Coffee (6070.860143753778t)
# Profit: 7827173.7
#
# Island B:
# Export: Steam Carriages (10139.973030000001t)
# Import: Caribou Meat (1078.993344t), Tortillas (11000.0t), Dynamite (11000.0t), Penny Farthings (11000.0t), Pocket Watches (11000.0t), Gramophones (11000.0t), Coffee (6070.860143753777t), Glasses (2293.4202612367244t), Light Bulbs (3225.1254777971953t), Champagne (3034.1980495116013t), Cigars (2866.775250193503t), Chocolate (6880.267685967349t)
# Profit: 41900258.0
#
# 11000	H	4520.675609090909	93.641793181911	33.5466516517678	6	600865.756900965	9910.25351867045	155.96976684175536
# Optimal, Profit 95.83 t/min, 33.71 min, Error 0.49%
# Optimal, Profit 94.83 t/min, 33.83 min, Error 0.37%
# Optimal, Profit 95.08 t/min, 33.80 min, Error 0.09%
# Optimal, Profit 95.01 t/min, 33.81 min, Error 0.02%
# Optimal, Profit 95.03 t/min, 33.81 min, Error 0.01%
# Optimal, Profit 95.03 t/min, 33.81 min, Error 0.00%
# Optimal, Profit 95.03 t/min, 33.81 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (10370.42685t)
# Import: Caribou Meat (1103.51727t), Tortillas (11250.0t), Dynamite (11250.0t), Penny Farthings (11250.0t), Pocket Watches (11250.0t), Gramophones (11250.0t), Coffee (6208.834054528459t), Glasses (2345.543379707555t), Light Bulbs (3298.4236866792726t), Champagne (3103.1570044278596t), Cigars (2931.9291465467613t), Chocolate (7036.637198249115t)
# Profit: 42852534.0
#
# Island B:
# Export: Caribou Meat (1103.51727t), Tortillas (11250.0t), Dynamite (11250.0t), Penny Farthings (11250.0t), Pocket Watches (11250.0t), Gramophones (11250.0t)
# Import: Steam Carriages (11250.0t), Coffee (6208.834054528459t)
# Profit: 8005065.1
#
# 11250	H	4520.675475555556	95.02665051570878	33.80907613658429	6	609751.8890626567	10112.717208083759	158.27638515951796
# Optimal, Profit 97.19 t/min, 33.97 min, Error 0.48%
# Optimal, Profit 96.19 t/min, 34.10 min, Error 0.36%
# Optimal, Profit 96.44 t/min, 34.07 min, Error 0.09%
# Optimal, Profit 96.38 t/min, 34.07 min, Error 0.02%
# Optimal, Profit 96.39 t/min, 34.07 min, Error 0.01%
# Optimal, Profit 96.39 t/min, 34.07 min, Error 0.00%
# Optimal, Profit 96.39 t/min, 34.07 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (10600.880664999999t)
# Import: Caribou Meat (1128.040842t), Tortillas (11500.0t), Dynamite (11500.0t), Penny Farthings (11500.0t), Pocket Watches (11500.0t), Gramophones (11500.0t), Coffee (6346.808038552771t), Glasses (2397.6665258502776t), Light Bulbs (3371.721934474988t), Champagne (3172.1159959540682t), Cigars (2997.083077489885t), Chocolate (7193.00679354664t)
# Profit: 43804811.0
#
# Island B:
# Export: Caribou Meat (1128.040842t), Tortillas (11500.0t), Dynamite (11500.0t), Penny Farthings (11500.0t), Pocket Watches (11500.0t), Gramophones (11500.0t)
# Import: Steam Carriages (11500.0t), Coffee (6346.808038552772t)
# Profit: 8182956.1
#
# 11500	H	4520.6754	96.3901765907164	34.07150046532094	6	618501.1461974712	10314.273303047014	160.547474133524
# Optimal, Profit 98.53 t/min, 34.24 min, Error 0.48%
# Optimal, Profit 97.54 t/min, 34.36 min, Error 0.36%
# Optimal, Profit 97.78 t/min, 34.33 min, Error 0.09%
# Optimal, Profit 97.72 t/min, 34.34 min, Error 0.02%
# Optimal, Profit 97.74 t/min, 34.33 min, Error 0.01%
# Optimal, Profit 97.73 t/min, 34.33 min, Error 0.00%
# Optimal, Profit 97.73 t/min, 34.33 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (10831.334475t)
# Import: Caribou Meat (1152.5647732500001t), Tortillas (11750.0t), Dynamite (11750.0t), Penny Farthings (11750.0t), Pocket Watches (11750.0t), Gramophones (11750.0t), Coffee (6484.781827244732t), Glasses (2449.7895982012874t), Light Bulbs (3445.0200785010006t), Champagne (3241.0748898537418t), Cigars (3062.2369161933684t), Chocolate (7349.376167468802t)
# Profit: 44757086.0
#
# Island B:
# Export: Caribou Meat (1152.5647732500001t), Tortillas (11750.0t), Dynamite (11750.0t), Penny Farthings (11750.0t), Pocket Watches (11750.0t), Gramophones (11750.0t)
# Import: Steam Carriages (11750.0t), Coffee (6484.781827244732t)
# Profit: 8360847.5
#
# 11750	H	4520.675191489362	97.73285561057685	34.3339249508003	6	627116.6352662914	10514.927823414131	162.78384025334117
# Optimal, Profit 99.85 t/min, 34.50 min, Error 0.48%
# Optimal, Profit 98.86 t/min, 34.62 min, Error 0.36%
# Optimal, Profit 99.10 t/min, 34.59 min, Error 0.09%
# Optimal, Profit 99.04 t/min, 34.60 min, Error 0.02%
# Optimal, Profit 99.06 t/min, 34.60 min, Error 0.01%
# Optimal, Profit 99.05 t/min, 34.60 min, Error 0.00%
# Optimal, Profit 99.06 t/min, 34.60 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1177.088496t), Tortillas (12000.0t), Dynamite (12000.0t), Penny Farthings (12000.0t), Pocket Watches (12000.0t), Gramophones (12000.0t)
# Import: Steam Carriages (12000.0t), Coffee (6622.755835685589t)
# Profit: 8538738.7
#
# Island B:
# Export: Steam Carriages (11061.788279999999t)
# Import: Caribou Meat (1177.088496t), Tortillas (12000.0t), Dynamite (12000.0t), Penny Farthings (12000.0t), Pocket Watches (12000.0t), Gramophones (12000.0t), Coffee (6622.755835685589t), Glasses (2501.912753567975t), Light Bulbs (3518.318339267929t), Champagne (3310.0338935832674t), Cigars (3127.390858666447t), Chocolate (7505.745790438248t)
# Profit: 45709363.0
#
# 12000	H	4520.675141666667	99.05516886158976	34.59634934807453	6	635601.4445104563	10714.686859182346	164.98628514941018
# Optimal, Profit 101.15 t/min, 34.76 min, Error 0.47%
# Optimal, Profit 100.16 t/min, 34.88 min, Error 0.36%
# Optimal, Profit 100.41 t/min, 34.85 min, Error 0.09%
# Optimal, Profit 100.35 t/min, 34.86 min, Error 0.02%
# Optimal, Profit 100.36 t/min, 34.86 min, Error 0.01%
# Optimal, Profit 100.36 t/min, 34.86 min, Error 0.00%
# Optimal, Profit 100.36 t/min, 34.86 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (11292.2422025t)
# Import: Caribou Meat (1201.6122265t), Tortillas (12250.0t), Dynamite (12250.0t), Penny Farthings (12250.0t), Pocket Watches (12250.0t), Gramophones (12250.0t), Coffee (6760.729722043726t), Glasses (2554.0358628148406t), Light Bulbs (3591.616535178793t), Champagne (3378.992836296208t), Cigars (3192.54474348975t), Chocolate (7662.115275048091t)
# Profit: 46661639.0
#
# Island B:
# Export: Caribou Meat (1201.6122265t), Tortillas (12250.0t), Dynamite (12250.0t), Penny Farthings (12250.0t), Pocket Watches (12250.0t), Gramophones (12250.0t)
# Import: Steam Carriages (12250.0t), Coffee (6760.729722043726t)
# Profit: 8716629.9
#
# 12250	H	4520.6750122448975	100.35757097657623	34.85877374632731	6	643958.4911455044	10913.556379122934	167.15556605813893
# Optimal, Profit 102.43 t/min, 35.02 min, Error 0.47%
# Optimal, Profit 101.45 t/min, 35.15 min, Error 0.35%
# Optimal, Profit 101.69 t/min, 35.12 min, Error 0.09%
# Optimal, Profit 101.63 t/min, 35.12 min, Error 0.02%
# Optimal, Profit 101.64 t/min, 35.12 min, Error 0.01%
# Optimal, Profit 101.64 t/min, 35.12 min, Error 0.00%
# Optimal, Profit 101.64 t/min, 35.12 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1226.1359625t), Tortillas (12500.0t), Dynamite (12500.0t), Penny Farthings (12500.0t), Pocket Watches (12500.0t), Gramophones (12500.0t)
# Import: Steam Carriages (12500.0t), Coffee (6898.703608401864t)
# Profit: 8894521.1
#
# Island B:
# Export: Steam Carriages (11522.696t)
# Import: Caribou Meat (1226.1359625t), Tortillas (12500.0t), Dynamite (12500.0t), Penny Farthings (12500.0t), Pocket Watches (12500.0t), Gramophones (12500.0t), Coffee (6898.703608401863t), Glasses (2606.158972061707t), Light Bulbs (3664.9147310896574t), Champagne (3447.9517790091495t), Cigars (3257.698628313054t), Chocolate (7818.484759657936t)
# Profit: 47613915.0
#
# 12500	H	4520.6748880000005	101.64051008092206	35.121198145274526	6	652190.6506310996	11111.54229813608	169.29242937715154
# Optimal, Profit 103.69 t/min, 35.28 min, Error 0.47%
# Optimal, Profit 102.71 t/min, 35.41 min, Error 0.35%
# Optimal, Profit 102.95 t/min, 35.38 min, Error 0.09%
# Optimal, Profit 102.89 t/min, 35.39 min, Error 0.02%
# Optimal, Profit 102.91 t/min, 35.38 min, Error 0.01%
# Optimal, Profit 102.90 t/min, 35.38 min, Error 0.00%
# Optimal, Profit 102.90 t/min, 35.38 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (11753.1497925t)
# Import: Caribou Meat (1250.65972725t), Tortillas (12750.0t), Dynamite (12750.0t), Penny Farthings (12750.0t), Pocket Watches (12750.0t), Gramophones (12750.0t), Coffee (7036.677494759999t), Glasses (2658.282081308573t), Light Bulbs (3738.212927000521t), Champagne (3516.91072172209t), Cigars (3322.852513136357t), Chocolate (7974.854244267778t)
# Profit: 48566191.0
#
# Island B:
# Export: Caribou Meat (1250.65972725t), Tortillas (12750.0t), Dynamite (12750.0t), Penny Farthings (12750.0t), Pocket Watches (12750.0t), Gramophones (12750.0t)
# Import: Steam Carriages (12750.0t), Coffee (7036.677494759999t)
# Profit: 9072412.3
#
# 12750	H	4520.674768627451	102.90441917518548	35.383622560227664	6	660300.7013763186	11308.650494331956	171.39759631215978
# Optimal, Profit 104.94 t/min, 35.55 min, Error 0.46%
# Optimal, Profit 103.96 t/min, 35.67 min, Error 0.35%
# Optimal, Profit 104.20 t/min, 35.64 min, Error 0.09%
# Optimal, Profit 104.14 t/min, 35.65 min, Error 0.02%
# Optimal, Profit 104.15 t/min, 35.65 min, Error 0.01%
# Optimal, Profit 104.15 t/min, 35.65 min, Error 0.00%
# Optimal, Profit 104.15 t/min, 35.65 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (11983.60358t)
# Import: Caribou Meat (1275.183663t), Tortillas (13000.0t), Dynamite (13000.0t), Penny Farthings (13000.0t), Pocket Watches (13000.0t), Gramophones (13000.0t), Coffee (7174.651405534681t), Glasses (2710.4051997794036t), Light Bulbs (3811.5111358825984t), Champagne (3585.869676638348t), Cigars (3388.0064094896156t), Chocolate (8131.223756549543t)
# Profit: 49518467.0
#
# Island B:
# Export: Caribou Meat (1275.183663t), Tortillas (13000.0t), Dynamite (13000.0t), Penny Farthings (13000.0t), Pocket Watches (13000.0t), Gramophones (13000.0t)
# Import: Steam Carriages (13000.0t), Coffee (7174.651405534681t)
# Profit: 9250303.7
#
# 13000	H	4520.67466923077	104.14971874509392	35.6460470462752	6	668291.3414870637	11504.886778392342	173.47176722417387
# Optimal, Profit 106.16 t/min, 35.81 min, Error 0.46%
# Optimal, Profit 105.18 t/min, 35.93 min, Error 0.34%
# Optimal, Profit 105.42 t/min, 35.90 min, Error 0.09%
# Optimal, Profit 105.36 t/min, 35.91 min, Error 0.02%
# Optimal, Profit 105.38 t/min, 35.91 min, Error 0.01%
# Optimal, Profit 105.38 t/min, 35.91 min, Error 0.00%
# Optimal, Profit 105.38 t/min, 35.91 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (12214.057495000001t)
# Import: Caribou Meat (1299.707393t), Tortillas (13250.0t), Dynamite (13250.0t), Penny Farthings (13250.0t), Pocket Watches (13250.0t), Gramophones (13250.0t), Coffee (7312.6254139755365t), Glasses (2762.5283551460907t), Light Bulbs (3884.8093966495258t), Champagne (3654.828680367874t), Cigars (3453.1603519626938t), Chocolate (8287.593379518989t)
# Profit: 50470744.0
#
# Island B:
# Export: Caribou Meat (1299.707393t), Tortillas (13250.0t), Dynamite (13250.0t), Penny Farthings (13250.0t), Pocket Watches (13250.0t), Gramophones (13250.0t)
# Import: Steam Carriages (13250.0t), Coffee (7312.6254139755365t)
# Profit: 9428194.9
#
# 13250	H	4520.674633962264	105.37681830882697	35.908471444464844	6	676165.1986944216	11700.256969061187	175.5156242066567
# Optimal, Profit 107.37 t/min, 36.07 min, Error 0.46%
# Optimal, Profit 106.39 t/min, 36.20 min, Error 0.34%
# Optimal, Profit 106.63 t/min, 36.16 min, Error 0.08%
# Optimal, Profit 106.57 t/min, 36.17 min, Error 0.02%
# Optimal, Profit 106.59 t/min, 36.17 min, Error 0.01%
# Optimal, Profit 106.59 t/min, 36.17 min, Error 0.00%
# Optimal, Profit 106.59 t/min, 36.17 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1324.231119t), Tortillas (13500.0t), Dynamite (13500.0t), Penny Farthings (13500.0t), Pocket Watches (13500.0t), Gramophones (13500.0t)
# Import: Steam Carriages (13500.0t), Coffee (7450.5993003336725t)
# Profit: 9606086.1
#
# Island B:
# Export: Steam Carriages (12444.511274999999t)
# Import: Caribou Meat (1324.231119t), Tortillas (13500.0t), Dynamite (13500.0t), Penny Farthings (13500.0t), Pocket Watches (13500.0t), Gramophones (13500.0t), Coffee (7450.5993003336725t), Glasses (2814.6514643929568t), Light Bulbs (3958.10759256039t), Champagne (3723.7876230808147t), Cigars (3518.3142367859973t), Chocolate (8443.962864128831t)
# Profit: 51423020.0
#
# 13500	H	4520.674525925926	106.58611060425852	36.17089584214944	6	683924.7930562834	11894.766751229728	177.52982140379478
# Optimal, Profit 108.56 t/min, 36.33 min, Error 0.45%
# Optimal, Profit 107.59 t/min, 36.46 min, Error 0.34%
# Optimal, Profit 107.83 t/min, 36.43 min, Error 0.08%
# Optimal, Profit 107.77 t/min, 36.43 min, Error 0.02%
# Optimal, Profit 107.78 t/min, 36.43 min, Error 0.01%
# Optimal, Profit 107.78 t/min, 36.43 min, Error 0.00%
# Optimal, Profit 107.78 t/min, 36.43 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Steam Carriages (12674.9651875t)
# Import: Caribou Meat (1348.7548525t), Tortillas (13750.0t), Dynamite (13750.0t), Penny Farthings (13750.0t), Pocket Watches (13750.0t), Gramophones (13750.0t), Coffee (7588.57318669181t), Glasses (2866.7745736398233t), Light Bulbs (4031.405788471255t), Champagne (3792.746565793756t), Cigars (3583.4681216093013t), Chocolate (8600.332348738677t)
# Profit: 52375296.0
#
# Island B:
# Export: Caribou Meat (1348.7548525t), Tortillas (13750.0t), Dynamite (13750.0t), Penny Farthings (13750.0t), Pocket Watches (13750.0t), Gramophones (13750.0t)
# Import: Steam Carriages (13750.0t), Coffee (7588.57318669181t)
# Profit: 9783977.3
#
# 13750	H	4520.674421818182	107.77798215125459	36.43332024078099	6	691572.604731817	12088.421812123013	179.51500260306096
# Optimal, Profit 109.73 t/min, 36.60 min, Error 0.45%
# Optimal, Profit 108.76 t/min, 36.72 min, Error 0.34%
# Optimal, Profit 109.00 t/min, 36.69 min, Error 0.08%
# Optimal, Profit 108.94 t/min, 36.70 min, Error 0.02%
# Optimal, Profit 108.96 t/min, 36.70 min, Error 0.01%
# Optimal, Profit 108.95 t/min, 36.70 min, Error 0.00%
# Optimal, Profit 108.95 t/min, 36.70 min, Error 0.00%
#
# Pyramid:
# 1: Steam Carriages
# 2: Pocket Watches, Gramophones
# 3: Tortillas, Dynamite, Penny Farthings
# 4: Caribou Meat
#
# Island A:
# Export: Caribou Meat (1373.278802t), Tortillas (14000.0t), Dynamite (14000.0t), Penny Farthings (14000.0t), Pocket Watches (14000.0t), Gramophones (14000.0t)
# Import: Steam Carriages (14000.0t), Coffee (7726.547097466492t)
# Profit: 9961868.7
#
# Island B:
# Export: Steam Carriages (12905.41896t)
# Import: Caribou Meat (1373.278802t), Tortillas (14000.0t), Dynamite (14000.0t), Penny Farthings (14000.0t), Pocket Watches (14000.0t), Gramophones (14000.0t), Coffee (7726.547097466492t), Glasses (2918.897692110654t), Light Bulbs (4104.703997353332t), Champagne (3861.7055207100148t), Cigars (3648.62201796256t), Chocolate (8756.701861020441t)
# Profit: 53327572.0
#
# 14000	H	4520.674335714286	108.95280675977602	36.69574473475259	6	699111.0323252932	12281.227731717086	181.47179042231045
# 4000	H	4736.349475	43.97934505108558	27.213089154863066	7	282199.66271677456	3839.1154794113017	73.25199529387035
# 4250	H	4736.690635294118	46.17908128628837	27.538579416853775	7	296314.580138101	4068.877516583906	76.91587587603134
# 4500	H	4736.688755555555	48.32377440128681	27.864380059549436	7	310076.3056249295	4297.4497660220495	80.48807663946185
# 4750	H	4736.687305263158	50.418896510397325	28.190180708433036	7	323519.9517696065	4524.881692754711	83.97771193754048
# 5000	H	4736.68578	52.46614195042674	28.515981289249332	7	336656.39052292745	4751.181822648902	87.38760385758239
# 5250	H	4736.68460952381	54.46713787782201	28.841781876253563	7	349496.06276344537	4976.358571949727	90.7204625912982
# 5500	H	4736.683345454545	56.42342924568309	29.167582518949224	7	362048.88190035766	5200.420276628219	93.97886141250714
# 5750	H	4736.682191304348	58.33650012733931	29.49338309976552	7	374324.3706992374	5423.375216400787	97.16527219368506
# 6000	H	4736.681316666666	60.207769267157566	29.819183748649117	7	386331.63273316773	5645.231549162986	100.28205799539059
# 6250	H	4736.680336	62.038587675603196	30.144984329465412	7	398079.336951111	5865.997402875544	103.33146906059878
# 6500	H	4736.719599999999	63.830919470340184	30.470726131073267	7	409580.0863907356	6085.692749341933	106.31677682360939
# 6750	H	4714.757007407407	65.69305371222086	30.60317658085778	7	421528.7330652523	6306.215672377091	109.41834753968878
# 7000	H	4714.750457142857	67.42399017517342	30.921828822887473	7	432635.5307099646	6523.890868141727	112.30139524062447
# 7250	H	4714.750234482759	69.1197342197388	31.240466389327075	7	443516.5112446785	6740.51326894116	115.12582645095343
# 7500	H	4714.749906666666	70.7812341723632	31.559103962711113	7	454177.7597396233	6956.088342025454	117.8932207031651
# 7750	H	4714.749587096774	72.4095184997236	31.87774153849522	7	464625.87549610774	7170.623663082147	120.60529101131404
# 8000	H	4520.7227375	75.1594932761939	30.397431362987284	6	482271.4760274053	7407.622513517215	125.1856488849994
# 8250	H	4520.677575757576	76.84373091327274	30.659983044823186	6	493078.62407761964	7621.451347088595	127.99091502349576
# 8500	H	4520.677329411765	78.5004249758141	30.92240746088112	6	503709.03490185994	7834.317060790604	130.75030458538438
# 8750	H	4520.677097142858	80.12923626878592	31.184831946044824	6	514160.5320074217	8046.204374918402	133.46325260743387
# 9000	H	4520.676866666667	81.7308630239646	31.44725634413977	6	524437.5956968553	8257.120054463736	136.13092206446206
# 9250	H	4520.676659459459	83.30598030218408	31.70968076016614	6	534544.5575930951	8467.070741535015	138.754437337766
# 9500	H	4520.676557894736	84.85524253964967	31.97210515819796	6	544485.61697824	8676.063058021873	141.33488845626212
# 9750	H	4520.676358974359	86.37927743416738	32.234529555535325	6	554264.8015636838	8884.103544018111	143.87332091339007
# 10000	H	4520.6761799999995	87.8786980429041	32.496954041077814	6	563886.0451170969	9091.198669773243	146.37075581714166
# 10250	H	4520.676	89.354095977323	32.75937843933058	6	573353.1437967705	9297.35489872248	148.82817855554532
# 10500	H	4520.675838095238	90.8060440682925	33.021802855135995	6	582669.7732526643	9502.578580852944	151.24654323567182
# 10750	H	4520.67576744186	92.23509859122721	33.28422725269432	6	591839.5029043362	9706.876036571828	153.62677638982865
# 11000	H	4520.675609090909	93.641793181911	33.5466516517678	6	600865.756900965	9910.25351867045	155.96976684175536
# 11250	H	4520.675475555556	95.02665051570878	33.80907613658429	6	609751.8890626567	10112.717208083759	158.27638515951796
# 11500	H	4520.6754	96.3901765907164	34.07150046532094	6	618501.1461974712	10314.273303047014	160.547474133524
# 11750	H	4520.675191489362	97.73285561057685	34.3339249508003	6	627116.6352662914	10514.927823414131	162.78384025334117
# 12000	H	4520.675141666667	99.05516886158976	34.59634934807453	6	635601.4445104563	10714.686859182346	164.98628514941018
# 12250	H	4520.6750122448975	100.35757097657623	34.85877374632731	6	643958.4911455044	10913.556379122934	167.15556605813893
# 12500	H	4520.6748880000005	101.64051008092206	35.121198145274526	6	652190.6506310996	11111.54229813608	169.29242937715154
# 12750	H	4520.674768627451	102.90441917518548	35.383622560227664	6	660300.7013763186	11308.650494331956	171.39759631215978
# 13000	H	4520.67466923077	104.14971874509392	35.6460470462752	6	668291.3414870637	11504.886778392342	173.47176722417387
# 13250	H	4520.674633962264	105.37681830882697	35.908471444464844	6	676165.1986944216	11700.256969061187	175.5156242066567
# 13500	H	4520.674525925926	106.58611060425852	36.17089584214944	6	683924.7930562834	11894.766751229728	177.52982140379478
# 13750	H	4520.674421818182	107.77798215125459	36.43332024078099	6	691572.604731817	12088.421812123013	179.51500260306096
# 14000	H	4520.674335714286	108.95280675977602	36.69574473475259	6	699111.0323252932	12281.227731717086	181.47179042231045
